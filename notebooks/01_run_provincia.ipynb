# %%
from pathlib import Path
import os
import sys
import shutil
import importlib
import subprocess
import yaml
from time import perf_counter

# Navegar al root del proyecto
root = Path.cwd().resolve()
while root != root.parent and not (root / "configs").exists():
    root = root.parent
os.chdir(root)

if str(root) not in sys.path:
    sys.path.insert(0, str(root))

# Optimizaciones de rendimiento
print("="*60)
print("INICIALIZANDO")
print("="*60)

try:
    from src.utils.performance import enable_pandas_performance, get_optimal_workers
    enable_pandas_performance()
    workers = get_optimal_workers()
    print(f"âœ“ Optimizaciones habilitadas")
    print(f"âœ“ CPU cores: {os.cpu_count()}")
    print(f"âœ“ Workers: {workers}")
except Exception as e:
    print(f"âš  Optimizaciones no disponibles: {e}")
    workers = 1

# Verificar geopandas
try:
    import geopandas as gpd
    print(f"âœ“ geopandas {gpd.__version__}")
except Exception:
    print("Instalando geopandas...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "geopandas"])
    import geopandas as gpd
    print(f"âœ“ geopandas {gpd.__version__}")

# Reload modules
import src.reporting.render_report as render_report
importlib.reload(render_report)
from src.reporting.render_report import run_provincia

# Cargar provincias disponibles
provincias_cfg_path = Path("configs") / "provincias.yaml"
provincias_cfg = {}
if provincias_cfg_path.exists():
    provincias_cfg = yaml.safe_load(provincias_cfg_path.read_text(encoding="utf-8")) or {}

prov_map = provincias_cfg.get("provincias", {}) or {}

# Ordenar con PROVINCIA al final
all_provs = sorted(prov_map.keys())
if "PROVINCIA" in all_provs:
    all_provs.remove("PROVINCIA")
    available_provinces = all_provs + ["PROVINCIA"]
else:
    available_provinces = all_provs

print("\n" + "="*60)
print("SELECCIÃ“N DE PROVINCIA")
print("="*60)
print("\nProvincias disponibles:")

# Mostrar en 3 columnas
import math
n_cols = 3
n_items = len(available_provinces)
n_rows = math.ceil(n_items / n_cols)
col_width = max(len(p) for p in available_provinces) + 6  # "XX. " + nombre + espacio

for row in range(n_rows):
    line = ""
    for col in range(n_cols):
        idx = col * n_rows + row
        if idx < n_items:
            entry = f"{idx + 1:02d}. {available_provinces[idx]}"
            line += f"  {entry:<{col_width}}"
    print(line.rstrip())

# SelecciÃ³n de provincia
selected_province = None
while selected_province is None:
    choice = input("\nProvincia (nÃºmero o nombre): ").strip()
    if not choice:
        print("âš  Debes ingresar una provincia vÃ¡lida.")
        continue
    if choice.isdigit():
        idx = int(choice)
        if 1 <= idx <= len(available_provinces):
            selected_province = available_provinces[idx - 1]
            break
    else:
        choice_norm = choice.upper().strip()
        if choice_norm in available_provinces:
            selected_province = choice_norm
            break
    print("âš  Provincia invÃ¡lida, intenta otra vez.")

print(f"\nâœ“ Provincia seleccionada: {selected_province}")

# SelecciÃ³n de intervalo
print("\n" + "="*60)
print("INTERVALO DE AÃ‘OS")
print("="*60)

use_all_years = input("\nÂ¿Usar todo el intervalo 2000-2024? (s/N): ").strip().lower() == "s"

if use_all_years:
    start_year = 2000
    end_year = 2024
else:
    # Pedir aÃ±o inicio
    while True:
        start_input = input("AÃ±o inicio (2000-2024): ").strip()
        try:
            start_year = int(start_input)
            if 2000 <= start_year <= 2024:
                break
            print("âš  AÃ±o debe estar entre 2000 y 2024")
        except ValueError:
            print("âš  Ingresa un aÃ±o vÃ¡lido")
    
    # Pedir aÃ±o fin
    while True:
        end_input = input(f"AÃ±o fin ({start_year}-2024): ").strip()
        try:
            end_year = int(end_input)
            if start_year <= end_year <= 2024:
                break
            print(f"âš  AÃ±o debe estar entre {start_year} y 2024")
        except ValueError:
            print("âš  Ingresa un aÃ±o vÃ¡lido")

print(f"\nâœ“ Intervalo: {start_year}-{end_year}")

# Modo pÃºblico (siempre activado)
public_mode = True
print(f"âœ“ Modo pÃºblico: activado (datos anonimizados)")

# Construir config override con intervalo personalizado
def build_configs_override(start_year: int, end_year: int, use_all_years: bool) -> Path:
    base = Path("configs")
    target = Path("notebooks") / "configs_override"
    target.mkdir(parents=True, exist_ok=True)
    
    global_cfg = yaml.safe_load((base / "global.yaml").read_text(encoding="utf-8")) or {}
    if not use_all_years:
        global_cfg["window_start_year"] = int(start_year)
        global_cfg["window_end_year"] = int(end_year)
    (target / "global.yaml").write_text(yaml.safe_dump(global_cfg, sort_keys=False), encoding="utf-8")
    
    if (base / "provincias.yaml").exists():
        (target / "provincias.yaml").write_text(
            (base / "provincias.yaml").read_text(encoding="utf-8"),
            encoding="utf-8",
        )
    return target

def resolve_raw_path(province: str) -> str | None:
    meta = prov_map.get(province.upper())
    if not meta:
        return None
    return meta.get("raw_path")

# Procesamiento
print("\n" + "="*60)
print("PROCESANDO")
print("="*60 + "\n")

cfg_dir = build_configs_override(start_year, end_year, use_all_years)
raw_path = resolve_raw_path(selected_province)

start_time = perf_counter()

try:
    out_base = run_provincia(
        selected_province,
        configs_dir=str(cfg_dir),
        raw_dir="data/raw",
        raw_path=raw_path,
        public_mode=public_mode,
    )
    elapsed = perf_counter() - start_time
    
    print("\n" + "="*60)
    print("COMPLETADO")
    print("="*60)
    print(f"\n Provincia: {selected_province}")
    print(f" Intervalo: {start_year}-{end_year}")
    print(f" Output: {out_base}")
    print(f" Tiempo: {elapsed:.2f}s ({elapsed/60:.2f} min)")
    
except Exception as e:
    elapsed = perf_counter() - start_time
    print("\n" + "="*60)
    print("ERROR")
    print("="*60)
    print(f"\n {selected_province}: {e}")
    print(f"Tiempo: {elapsed:.2f}s")
    
finally:
    # Cleanup
    
    shutil.rmtree(cfg_dir, ignore_errors=True)
    print(f"\nâœ“ Cleanup: configs_override eliminado")

print("\nProceso finalizado!")
# Out:
# ============================================================
# INICIALIZANDO
# ============================================================
# âœ“ Optimizaciones habilitadas
# âœ“ CPU cores: 12
# âœ“ Workers: 8
# âœ“ geopandas 1.1.2
#
# ============================================================
# SELECCIÃ“N DE PROVINCIA
# ============================================================
#
# Provincias disponibles:
#   01. AZUAY                             10. GUAYAS                            19. PICHINCHA
#   02. BOLIVAR                           11. IMBABURA                          20. SANTA ELENA
#   03. CARCHI                            12. LOJA                              21. SANTO DOMINGO DE LOS TSACHILAS
#   04. CAÃ‘AR                             13. LOS RIOS                          22. SUCUMBIOS
#   05. CHIMBORAZO                        14. MANABI                            23. TUNGURAHUA
#   06. COTOPAXI                          15. MORONA SANTIAGO                   24. ZAMORA CHINCHIPE
#   07. EL ORO                            16. NAPO                              25. PROVINCIA
#   08. ESMERALDAS                        17. ORELLANA
#   09. GALAPAGOS                         18. PASTAZA
#
# âœ“ Provincia seleccionada: BOLIVAR
#
# ============================================================
# INTERVALO DE AÃ‘OS
# ============================================================
#
# âœ“ Intervalo: 2000-2024
# âœ“ Modo pÃºblico: activado (datos anonimizados)
#
# ============================================================
# PROCESANDO
# ============================================================
#
# Limpieza previa: 7 carpetas __pycache__ eliminadas.
# Iniciando pipeline para BOLIVAR (15 etapas)...
#   01. Carga del raw
#   02. NormalizaciÃ³n de campos
#   03. Filtro universo (SOCIEDAD)
#   04. Filtro provincia
#   05. Filtro codigos omitidos
#   06. QC raw
#   07. Colapso a RUC
#   08. QC RUC
#   09. DemografÃ­a y cohortes
#   10. Cantones y geografÃ­a
#   11. Macro sectores y actividades
#   12. KPIs de supervivencia
#   13. Figuras base
#   14. Comparativas / KM estratificado
#   15. MÃ©tricas ejecutivas
# ----------------------------------------
# [  6.7% Â· 1/15] Carga del raw â€” 80,504 filas leÃ­das desde data\raw\SRI_RUC_Bolivar.csv | tiempo 1s
# [ 13.3% Â· 2/15] NormalizaciÃ³n de campos â€” 80,504 filas normalizadas | tiempo 1s
# [ 20.0% Â· 3/15] Filtro universo (SOCIEDAD) â€” 80,504 -> 4,052 registros SOCIEDAD | tiempo 1m 6s
# [ 26.7% Â· 4/15] Filtro provincia â€” 4,052 -> 3,918 registros en BOLIVAR | tiempo 1m 6s
# [ 33.3% Â· 5/15] Filtro codigos omitidos â€” 3,918 -> 1,968 excluyendo 6 codigos en CODIGO_CIIU | tiempo 1m 6s
# [ 40.0% Â· 6/15] QC raw â€” QC raw listo (RUC Ãºnicos: 1606) | tiempo 1m 6s
# [ 46.7% Â· 7/15] Colapso a RUC â€” 1,606 RUC en ruc_master.parquet | tiempo 1m 18s
# [ 53.3% Â· 8/15] QC RUC â€” QC RUC listo (eventos: 661, censored: 945) | tiempo 1m 19s
# [ 60.0% Â· 9/15] DemografÃ­a y cohortes â€” DemografÃ­a (25 filas) y cohortes (6 filas) listos | tiempo 1m 19s
# [ 66.7% Â· 10/15] Cantones y geografÃ­a â€” Cantones top calculados (7 filas) y mÃ©tricas de concentraciÃ³n listas | tiempo 1m 19s
# [ 73.3% Â· 11/15] Macro sectores y actividades â€” Macro sectores (21 filas) y actividades (10 filas) calculados. HHI=0.081 | tiempo 1m 19s
# [ 80.0% Â· 12/15] KPIs de supervivencia â€” KPIs de supervivencia listos (mediana 228.0 meses) | tiempo 1m 19s
# [ 86.7% Â· 13/15] Figuras base â€” 6 figuras base exportadas | tiempo 1m 21s
# [ 93.3% Â· 14/15] Comparativas / KM estratificado â€” Comparativas generadas (6 tablas / 6 figuras) | tiempo 1m 24s
# [100.0% Â· 15/15] MÃ©tricas ejecutivas â€” metrics.json y executive_kpis.csv generados | tiempo 1m 25s
# Pipeline completado en 1m 25s.
#
# ============================================================
# COMPLETADO
# ============================================================
#
#  Provincia: BOLIVAR
#  Intervalo: 2000-2024
#  Output: outputs\BOLIVAR
#  Tiempo: 85.26s (1.42 min)
#
# âœ“ Cleanup: configs_override eliminado
#
# Proceso finalizado!
